# %% [markdown]
# # The Battle of the Neighborhoods Week 1
# Introduction & Business Problem :
#
# Problem Background:
#
# AFRICA views The City of New York as the most prominent city in the United States of America. It is source of the financial capital in USA. a lot of immigrants are populating it therefore has adopted all the cultures all over the world. it is easy to fimd that everyone wants to do business in the area. It has a lot of business oppourtunities and the businesses propsper there. the business types include banking and finance, clothing shops,Business Corporation,Not-for-Profit Corporation,Limited Liability Company, General Partnership, Limited Partnership, Sole Proprietorship.
#
# according to New york times, The New York City restaurateur’s perennial lament — that staying afloat is tougher here than anywhere else in the country — grows louder each time another restaurant closes. Rents are astronomical, the complaint goes; wages are rising, regulations are byzantine, and don’t even talk about the price of fresh produce. A thorough analysis of the market and market rich areas is useful and assists in taking a business risk, a weel done research and analysis almost gurantees bonus profits.
#
# Problem statement:
#
# African cuisine is an industry which prepares and serves food and drink to customers that is native to african regions, either sitting in restaurants , vendoring, or takeaway. The City of New York well known for its diverse cuisine. as New York is populated by people froma allover the world, African cuisine is part of these cultures
#
# non native citizens offering different cuisines
#
# 1. italians came with New York-style pizza and pasta cuisine
# 2. Jewish immigrants and Irish immigrants - pastrami and corned beef
# 3. Asian food restaurants, sandwich joints, trattorias, diners, and coffeehouses are ubiquitous throughout the city
# 4. mobile food carts - Some 4,000 licensed by the city
# 5. Middle Eastern foods such as falafel and kebabs examples of modern New York street food
# 6. It has Pizza selling places,
#
# What we are going to study in this project is :
#
# 1. the city's Population
# 2. the City's Demographics
# 3. the availability of Markets, Wholesale markets around the area and what they sell
# 4. commercial outlets such as Gymnasiums, Entertainmnet areas, recreational sites nearby that are visisted regularly
# 5. as any place, they already restaurents, how is the competition in the location
# 5. what kind cuisine is appreciated in the area
# 6. New foods that have not been introduced
# 7. differents food per different area, etc
#
# Target audience
#
# Our target audience are all the intreprenuers who are looking to open restaurants coming frm all over the world,but most important the company from Africa that gave out this project to get a better reccomendation on the neighborhood that is best suitable for opening a restaurant
#
#
# acquiring the resuts of this analysis will yield the company with populrity and most importantly, high profits.

# %% [markdown]
# # Data required for the analysis
#
# One city will be analysed in this project : Newyork City.
#
# We will be using the below datasets for analysing Newyork city
#
# Neighborhood has a total of 5 boroughs and 306 neighborhoods. In order to explore the neighborhoods, we will essentially need a dataset that contains the 5 boroughs and the neighborhoods that exist in each borough as well as the the latitude and logitude coordinates of each neighborhood.
#
# This dataset exists for free on the web. Link to the dataset is : https://geo.nyu.edu/catalog/nyu_2451_34572
#
# Second data which will be used is the DOHMH african cuisines and Food Boxes dataset. In this we will be using the data of Farmers Markets.
#
# https://data.cityofnewyork.us/dataset/DOHMH-Farmers-Markets-and-Food-Boxes/8vwk-6iz2
#
# Website-https://www.grownyc.org/greenmarketco/foodbox
#
# GrowNYC's Fresh Food Box Program is a food access initiative that enables under-served communities to purchase fresh, healthy, and primarily regionally grown produce well below traditional selling prices.
#
# For the below analysis we will get data from wikipedia as given below :
#
# New York Population
# New York City Demographics
# Cuisine of New York city
# https://en.wikipedia.org/wiki/New_York_City
# https://en.wikipedia.org/wiki/Economy_of_New_York_City
# https://en.wikipedia.org/wiki/Portal:New_York_City
# https://en.wikipedia.org/wiki/Cuisine_of_New_York_City
# https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_New_York_City
#
# Newyork city geographical coordinates data will be utilized as input for the Foursquare API, that will be leveraged to provision venues information for each neighborhood.We will use the Foursquare API to explore neighborhoods in New York City. The below is image of the Foursquare API data.
